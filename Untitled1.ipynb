# %% [markdown]
# <a href="https://colab.research.google.com/github/kuznetsovgleb201307-web/-m1l2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install telebot

# %%
def game():
    guest = int(input('Hi! I am Bla Bla Bot! Decide this! 2 + 2 = ?'))
    rightwrong = ''
    if guest == 4:
        rightwrong = 'You are right!'
    else:
        rightwrong = 'Oh no! Wrong'
    return rightwrong

# %%
import random

def gen_pass(pass_length):
    elements = "+-/*!&$#?=@<>123456789"
    password = ""
    for i in range(pass_length):
        password += random.choice(elements)
    return password

# %%
import telebot
import os
import random

bot = telebot.TeleBot("token")

@bot.message_handler(commands=['start'])
def send_welcome(message):
    bot.reply_to(message, "Привет! Я твой Telegram бот. Напиши что-нибудь!Например /list!")

@bot.message_handler(commands=['hello'])
def send_hello(message):
    bot.reply_to(message, "Привет! Как дела?")

@bot.message_handler(commands=['bye'])
def send_bye(message):
    bot.reply_to(message, "Пока! Удачи!")

@bot.message_handler(commands=['password'])
def send_bye(message):
    bot.reply_to(message, gen_pass(12))


@bot.message_handler(commands=['game'])
def send_bye(message):
    bot.reply_to(message, "2+2")

@bot.message_handler(commands=['4'])
def send_bye(message):
    bot.reply_to(message, "правильно!")

@bot.message_handler(commands=['game2'])
def send_bye(message):
    bot.reply_to(message, "2+44")

@bot.message_handler(commands=['46'])
def send_bye(message):
    bot.reply_to(message, "правильно!")

@bot.message_handler(commands=['mem'])
def send_mem(message):
    imgo = random.choice(os.listdir('img'))
    with open(f'img/{imgo}', 'rb') as f:
        bot.send_photo(message.chat.id, f)

@bot.message_handler(commands=['memsecret'])
def send_mem(message):
    with open('memsecret/mem7.png', 'rb') as f:
        bot.send_photo(message.chat.id, f)

@bot.message_handler(commands=['kartinochka'])
def send_mem(message):
    karti = random.choice(os.listdir('kart'))
    with open(f'kart/{karti}', 'rb') as f:
        bot.send_photo(message.chat.id, f)


@bot.message_handler(commands=['list'])
def send_welcome(message):
    bot.reply_to(message, '''
/start        - перезапустить бота
/hello        - сказать привет
/bye          - сказать пока
/password     - сгенирировать рандомный пароль из 12 символов
/game         - сыграть в игру
/game2        - второй раунд
/mem          - рандомный мем
/kartinochka  - картинка
/memsecret    - секрет ''')

@bot.message_handler(func=lambda message: True)
def echo_all(message):
    bot.reply_to(message, message.text)

bot.polling()
